# %%
from glob import glob #Folders directories
import pandas as pd #Data Manipulation
import numpy as np #Linear algebra
import nltk #Natural Language Processing
from nltk.tokenize import word_tokenize #Used to tokenize words
from nltk.corpus import stopwords #Used to remove stop words
from nltk.stem import PorterStemmer ##Used to perform stemming
import re #Regulars expressions

# %% [markdown]
# ### Class for preprocessing stage

# %%
class preprocessing(object):
    def __init__(self, punct):
        #we define our punctuation signs to then remove them
        self.punct = punct 
        
    def cleaning(self, string):
        #Removing punctuation signs
        string = "".join([i for i in string if i not in self.punct])
        #Most of text have literally \n or \\n and we want to delete them
        string = string.replace("\\n", " ").replace("\n", " ")
        #Most of text have \\ or // literally among the words  and we want to delete them
        string = string.replace("\\", " ").replace("//", " ")
        #Most of text have -- or -- literally among the words  and we want to delete them
        string = string.replace("-", " ").replace("--", " ")
        #Taking only letters no numbers
        string = re.sub(r'\d+', '', string)
        string = ' '.join(string.split())
        #Tokenizing and lowering text
        string = word_tokenize(string.lower())
        #Removing stopwords
        stop_words = stopwords.words('english')
        cleaned_words = [w for w in string if w not in stop_words]
        stemmer = PorterStemmer()
        #Stemming 
        stemmed_words = [stemmer.stem(w) for w in cleaned_words]
        stem_words = " ".join(stemmed_words)
        return stem_words
        
        #Putting the cleaning method into a new column called clean text
    def addtoframe(selfdev, df):
        df['clean_text'] = df.body.apply(selfdev.cleaning)
        
        #Getting tags of words text
    def get_pos(self, string):
        string = nltk.word_tokenize(string)
        pos_string = nltk.pos_tag(string)
        return pos_string
        
        #Putting the tagging method into a new column called postag_text
    def postoframe(selfdev, df):
        df['postag_text'] = df.clean_text.apply(selfdev.get_pos)

# %%
#With the help of glob, we can read all jsons and put them into a single dataframe
jsons = sorted(glob('*.json'))
df = pd.concat((pd.read_json(file) for file in jsons),ignore_index=True)

# %%
#Shape of the dataframe
df.shape
# Out:
# (21578, 7)

# %%
#Types of columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21578 entries, 0 to 21577
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   title          20841 non-null  object
#  1   body           19043 non-null  object
#  2   date           21578 non-null  object
#  3   topics         11367 non-null  object
#  4   places         18798 non-null  object
#  5   id             21578 non-null  int64
#  6   organisations  881 non-null    object
# dtypes: int64(1), object(6)
# memory usage: 1.2+ MB

# %%
#Checking null values
df.isnull().sum()
# Out:
# title              737
# body              2535
# date                 0
# topics           10211
# places            2780
# id                   0
# organisations    20697
# dtype: int64

# %%
#Saving the shape of the rows before deleting null values
before = df.shape[0]

# %%
#Replacing null values with unknown word
df['title'] = df['title'].replace(np.nan,'unknown')
df['places'] = df['places'].replace(np.nan,'unknown')
df['organisations'] = df['organisations'].replace(np.nan,'unknown')

# %%
#Dropping null values
df = df.dropna()

# %%
##Saving the shape of the rows after deleting null values
after = df.shape[0]

# %%
after
# Out:
# 10377

# %%
#Percetage of data we have left from the dataset
percentage = round((after/before)*100,2)
print("The percentage left of data is: ",percentage,"%")
# Out:
# The percentage left of data is:  48.09 %

# %%
#Checking there is not null values again
df.isnull().sum()
# Out:
# title            0
# body             0
# date             0
# topics           0
# places           0
# id               0
# organisations    0
# dtype: int64

# %%
#Putting body column as string to better mnipulation
df['body'] = df['body'].astype(str)

# %%
#Calling our class with our punctuation signs to remove them
cleaning = preprocessing('\â€œ:â€&;?!"#$%&\'()*+,-./:;<=>?[\\]^_`{|}~¡¬´')

# %%
#Calling method of the class to put in the dataframe
preprocessing = cleaning.addtoframe(df)

# %%
df.columns
# Out:
# Index(['title', 'body', 'date', 'topics', 'places', 'id', 'organisations',
#        'clean_text'],
#       dtype='object')

# %%
#Watching dataframe
df
# Out:
#                                                    title  \
# 0                                     BAHIA COCOA REVIEW
# 4       NATIONAL AVERAGE PRICES FOR FARMER-OWNED RESERVE
# 5          ARGENTINE 1986/87 GRAIN/OILSEED REGISTRATIONS
# 8            CHAMPION PRODUCTS <CH> APPROVES STOCK SPLIT
# 9        COMPUTER TERMINAL SYSTEMS <CPML> COMPLETES SALE
# ...                                                  ...
# 21570      N.Z.'S CHASE CORP MAKES OFFER FOR ENTREGROWTH
# 21572  TOKYO DEALERS SEE DOLLAR POISED TO BREACH 140 YEN
# 21573  JAPAN/INDIA CONFERENCE CUTS GULF WAR RISK CHARGES
# 21574      SOVIET INDUSTRIAL GROWTH/TRADE SLOWER IN 1987
# 21575     SIX KILLED IN SOUTH AFRICAN GOLD MINE ACCIDENT
#
#                                                     body  \
# 0      Showers continued throughout the week in\nthe ...
# 4      The U.S. Agriculture Department\nreported the ...
# 5      Argentine grain board figures show\ncrop regis...
# 8      Champion Products Inc said its\nboard of direc...
# 9      Computer Terminal Systems Inc said\nit has com...
# ...                                                  ...
# 21570  Chase Corp Ltd <CHCA.WE> said it will\nmake an...
# 21572  Tokyo's foreign exchange market is watching\nn...
# 21573  The Japan/India-Pakistan-Gulf/Japan\nshipping ...
# 21574  The Soviet Union's industrial output is\ngrowi...
# 21575  Six black miners have been killed\nand two inj...
#
#                              date  \
# 0      1987-02-26 15:01:01.790000
# 4      1987-02-26 15:10:44.600000
# 5      1987-02-26 15:14:36.410000
# 8      1987-02-26 15:17:11.200000
# 9      1987-02-26 15:18:06.670000
# ...                           ...
# 21570  1987-10-19 01:35:27.640000
# 21572  1987-10-19 00:59:58.560000
# 21573  1987-10-19 00:34:08.940000
# 21574  1987-10-19 00:18:22.790000
# 21575  1987-10-19 00:05:11.260000
#
#                                                   topics  \
# 0                                                [cocoa]
# 4             [grain, wheat, corn, barley, oat, sorghum]
# 5      [veg-oil, linseed, lin-oil, soy-oil, sun-oil, ...
# 8                                                 [earn]
# 9                                                  [acq]
# ...                                                  ...
# 21570                                              [acq]
# 21572                               [money-fx, dlr, yen]
# 21573                                             [ship]
# 21574                                              [ipi]
# 21575                                             [gold]
#
#                                                 places     id organisations  \
# 0                          [el-salvador, usa, uruguay]      1       unknown
# 4                                                [usa]      5       unknown
# 5                                          [argentina]      6       unknown
# 8                                                [usa]      9       unknown
# 9                                                [usa]     10       unknown
# ...                                                ...    ...           ...
# 21570                                    [new-zealand]  21571       unknown
# 21572                       [japan, west-germany, usa]  21573       unknown
# 21573  [hong-kong, japan, india, pakistan, iran, iraq]  21574       unknown
# 21574                                           [ussr]  21575       unknown
# 21575                                   [south-africa]  21576       unknown
#
#                                               clean_text
# 0      shower continu throughout week bahia cocoa zon...
# 4      us agricultur depart report farmerown reserv n...
# 5      argentin grain board figur show crop registr g...
# 8      champion product inc said board director appro...
# 9      comput termin system inc said complet sale sha...
# ...                                                  ...
# 21570  chase corp ltd chcaw said make offer fullypaid...
# 21572  tokyo foreign exchang market watch nervous see...
# 21573  japanindiapakistangulfjapan ship confer said w...
# 21574  soviet union industri output grow slower pace ...
# 21575  six black miner kill two injur rock fall three...
#
# [10377 rows x 8 columns]

# %%
#Putting the postag on a column
cleaning.postoframe(df)

# %%
#Checking datafrme
df
# Out:
#                                                    title  \
# 0                                     BAHIA COCOA REVIEW
# 4       NATIONAL AVERAGE PRICES FOR FARMER-OWNED RESERVE
# 5          ARGENTINE 1986/87 GRAIN/OILSEED REGISTRATIONS
# 8            CHAMPION PRODUCTS <CH> APPROVES STOCK SPLIT
# 9        COMPUTER TERMINAL SYSTEMS <CPML> COMPLETES SALE
# ...                                                  ...
# 21570      N.Z.'S CHASE CORP MAKES OFFER FOR ENTREGROWTH
# 21572  TOKYO DEALERS SEE DOLLAR POISED TO BREACH 140 YEN
# 21573  JAPAN/INDIA CONFERENCE CUTS GULF WAR RISK CHARGES
# 21574      SOVIET INDUSTRIAL GROWTH/TRADE SLOWER IN 1987
# 21575     SIX KILLED IN SOUTH AFRICAN GOLD MINE ACCIDENT
#
#                                                     body  \
# 0      Showers continued throughout the week in\nthe ...
# 4      The U.S. Agriculture Department\nreported the ...
# 5      Argentine grain board figures show\ncrop regis...
# 8      Champion Products Inc said its\nboard of direc...
# 9      Computer Terminal Systems Inc said\nit has com...
# ...                                                  ...
# 21570  Chase Corp Ltd <CHCA.WE> said it will\nmake an...
# 21572  Tokyo's foreign exchange market is watching\nn...
# 21573  The Japan/India-Pakistan-Gulf/Japan\nshipping ...
# 21574  The Soviet Union's industrial output is\ngrowi...
# 21575  Six black miners have been killed\nand two inj...
#
#                              date  \
# 0      1987-02-26 15:01:01.790000
# 4      1987-02-26 15:10:44.600000
# 5      1987-02-26 15:14:36.410000
# 8      1987-02-26 15:17:11.200000
# 9      1987-02-26 15:18:06.670000
# ...                           ...
# 21570  1987-10-19 01:35:27.640000
# 21572  1987-10-19 00:59:58.560000
# 21573  1987-10-19 00:34:08.940000
# 21574  1987-10-19 00:18:22.790000
# 21575  1987-10-19 00:05:11.260000
#
#                                                   topics  \
# 0                                                [cocoa]
# 4             [grain, wheat, corn, barley, oat, sorghum]
# 5      [veg-oil, linseed, lin-oil, soy-oil, sun-oil, ...
# 8                                                 [earn]
# 9                                                  [acq]
# ...                                                  ...
# 21570                                              [acq]
# 21572                               [money-fx, dlr, yen]
# 21573                                             [ship]
# 21574                                              [ipi]
# 21575                                             [gold]
#
#                                                 places     id organisations  \
# 0                          [el-salvador, usa, uruguay]      1       unknown
# 4                                                [usa]      5       unknown
# 5                                          [argentina]      6       unknown
# 8                                                [usa]      9       unknown
# 9                                                [usa]     10       unknown
# ...                                                ...    ...           ...
# 21570                                    [new-zealand]  21571       unknown
# 21572                       [japan, west-germany, usa]  21573       unknown
# 21573  [hong-kong, japan, india, pakistan, iran, iraq]  21574       unknown
# 21574                                           [ussr]  21575       unknown
# 21575                                   [south-africa]  21576       unknown
#
#                                               clean_text  \
# 0      shower continu throughout week bahia cocoa zon...
# 4      us agricultur depart report farmerown reserv n...
# 5      argentin grain board figur show crop registr g...
# 8      champion product inc said board director appro...
# 9      comput termin system inc said complet sale sha...
# ...                                                  ...
# 21570  chase corp ltd chcaw said make offer fullypaid...
# 21572  tokyo foreign exchang market watch nervous see...
# 21573  japanindiapakistangulfjapan ship confer said w...
# 21574  soviet union industri output grow slower pace ...
# 21575  six black miner kill two injur rock fall three...
#
#                                              postag_text
# 0      [(shower, NN), (continu, NN), (throughout, IN)...
# 4      [(us, PRP), (agricultur, VBP), (depart, JJ), (...
# 5      [(argentin, NN), (grain, NN), (board, NN), (fi...
# 8      [(champion, NN), (product, NN), (inc, NN), (sa...
# 9      [(comput, NN), (termin, NN), (system, NN), (in...
# ...                                                  ...
# 21570  [(chase, NN), (corp, NN), (ltd, NN), (chcaw, N...
# 21572  [(tokyo, JJ), (foreign, JJ), (exchang, NN), (m...
# 21573  [(japanindiapakistangulfjapan, NN), (ship, NN)...
# 21574  [(soviet, JJ), (union, NN), (industri, NN), (o...
# 21575  [(six, CD), (black, JJ), (miner, NN), (kill, V...
#
# [10377 rows x 9 columns]

# %% [markdown]
# ## Checking the topics classes for the classification

# %%
#There are more than three types of topics, therefore we will need a multi-classifier
df.topics
# Out:
# 0                                                  [cocoa]
# 4               [grain, wheat, corn, barley, oat, sorghum]
# 5        [veg-oil, linseed, lin-oil, soy-oil, sun-oil, ...
# 8                                                   [earn]
# 9                                                    [acq]
#                                ...
# 21570                                                [acq]
# 21572                                 [money-fx, dlr, yen]
# 21573                                               [ship]
# 21574                                                [ipi]
# 21575                                               [gold]
# Name: topics, Length: 10377, dtype: object

# %%
#Putting topics column as string to better manipulation
df['topics'] = df['topics'].astype(str)

# %%
#Saving number of different classes in the topics columns
topics_number = df['topics'].value_counts()

# %%
len(topics_number)
# Out:
# 646

# %%
#Principal six top classes 
topics_number.head(6)
# Out:
# ['earn']        3735
# ['acq']         2125
# ['crude']        355
# ['trade']        333
# ['money-fx']     259
# ['interest']     211
# Name: topics, dtype: int64

# %% [markdown]
# ## Choosing the 6 most appeared topics to the classification

# %%
earns = df[df['topics'] == "['earn']"]
acqs = df[df['topics'] == "['acq']"]
crudes = df[df['topics'] == "['crude']"]
trades = df[df['topics'] == "['trade']"]
moneyfxs = df[df['topics'] == "['money-fx']"]
interests = df[df['topics'] == "['interest']"]

# %%
#Merging all those six classes into one
little = pd.concat([earns, acqs, crudes, trades, moneyfxs, interests]).reset_index(drop=True)

# %%
little
# Out:
#                                                   title  \
# 0           CHAMPION PRODUCTS <CH> APPROVES STOCK SPLIT
# 1                           COBANCO INC <CBCO> YEAR NET
# 2              AM INTERNATIONAL INC <AM> 2ND QTR JAN 31
# 3                    BROWN-FORMAN INC <BFD> 4TH QTR NET
# 4          DEAN FOODS <DF> SEES STRONG 4TH QTR EARNINGS
# ...                                                 ...
# 7013   LAWSON SAYS UK INTEREST RATE PROSPECTS UNCHANGED
# 7014        REAGAN SEES ROOM FOR INTEREST RATE DECLINES
# 7015                FED ARRANGES THREE-DAY SYSTEM REPOS
# 7016  FDIC'S SEIDMAN SAYS HIGHER RATES COULD HARM BANKS
# 7017    LUX FRANC BOND MARKET STALLED BY BELGIAN CRISIS
#
#                                                    body  \
# 0     Champion Products Inc said its\nboard of direc...
# 1     Shr 34 cts vs 1.19 dlrs\n    Net 807,000 vs 2,...
# 2     Oper shr loss two cts vs profit seven cts\n   ...
# 3     Shr one dlr vs 73 cts\n    Net 12.6 mln vs 15....
# 4     Dean Foods Co expects earnings for the\nfourth...
# ...                                                 ...
# 7013  U.K. Chancellor of the Exchequer Nigel\nLawson...
# 7014  President Reagan said he was pleased\nwith the...
# 7015  The Federal Reserve entered the\ngovernment se...
# 7016  Federal Deposit Insurance Corp Chairman\nWilli...
# 7017  The thriving market in Luxembourg\nfranc bond ...
#
#                             date        topics                 places     id  \
# 0     1987-02-26 15:17:11.200000      ['earn']                  [usa]      9
# 1     1987-02-26 15:18:59.340000      ['earn']                  [usa]     11
# 2     1987-02-26 15:20:13.090000      ['earn']                  [usa]     13
# 3     1987-02-26 15:20:27.170000      ['earn']                  [usa]     14
# 4     1987-02-26 15:26:26.780000      ['earn']                  [usa]     18
# ...                          ...           ...                    ...    ...
# 7013  1987-10-20 14:16:22.140000  ['interest']                   [uk]  20532
# 7014  1987-10-20 17:16:07.650000  ['interest']                  [usa]  20769
# 7015  1987-10-19 11:55:16.350000  ['interest']                  [usa]  21285
# 7016  1987-10-19 11:09:59.740000  ['interest']                  [usa]  21342
# 7017  1987-10-19 08:22:10.280000  ['interest']  [luxembourg, belgium]  21491
#
#      organisations                                         clean_text  \
# 0          unknown  champion product inc said board director appro...
# 1          unknown  shr ct vs dlr net vs asset mln vs mln deposit ...
# 2          unknown  oper shr loss two ct vs profit seven ct oper s...
# 3          unknown  shr one dlr vs ct net mln vs mln rev mln vs ml...
# 4          unknown  dean food co expect earn fourth quarter end ma...
# ...            ...                                                ...
# 7013       unknown  uk chancellor exchequ nigel lawson said collap...
# 7014       unknown  presid reagan said pleas action bank reduc pri...
# 7015       unknown  feder reserv enter govern secur market arrang ...
# 7016       unknown  feder deposit insur corp chairman william seid...
# 7017       unknown  thrive market luxembourg franc bond issu tempo...
#
#                                             postag_text
# 0     [(champion, NN), (product, NN), (inc, NN), (sa...
# 1     [(shr, NN), (ct, NN), (vs, JJ), (dlr, JJ), (ne...
# 2     [(oper, IN), (shr, JJ), (loss, NN), (two, CD),...
# 3     [(shr, VB), (one, CD), (dlr, NN), (vs, NN), (c...
# 4     [(dean, NN), (food, NN), (co, NN), (expect, VB...
# ...                                                 ...
# 7013  [(uk, JJ), (chancellor, NN), (exchequ, NN), (n...
# 7014  [(presid, NN), (reagan, NN), (said, VBD), (ple...
# 7015  [(feder, NN), (reserv, NN), (enter, NN), (gove...
# 7016  [(feder, NN), (deposit, NN), (insur, VBP), (co...
# 7017  [(thrive, JJ), (market, NN), (luxembourg, NN),...
#
# [7018 rows x 9 columns]

# %%
#Removing the brackets to better manipulation
little['topics_clean'] = little['topics'].str.strip('[]')

# %%
little
# Out:
#                                                   title  \
# 0           CHAMPION PRODUCTS <CH> APPROVES STOCK SPLIT
# 1                           COBANCO INC <CBCO> YEAR NET
# 2              AM INTERNATIONAL INC <AM> 2ND QTR JAN 31
# 3                    BROWN-FORMAN INC <BFD> 4TH QTR NET
# 4          DEAN FOODS <DF> SEES STRONG 4TH QTR EARNINGS
# ...                                                 ...
# 7013   LAWSON SAYS UK INTEREST RATE PROSPECTS UNCHANGED
# 7014        REAGAN SEES ROOM FOR INTEREST RATE DECLINES
# 7015                FED ARRANGES THREE-DAY SYSTEM REPOS
# 7016  FDIC'S SEIDMAN SAYS HIGHER RATES COULD HARM BANKS
# 7017    LUX FRANC BOND MARKET STALLED BY BELGIAN CRISIS
#
#                                                    body  \
# 0     Champion Products Inc said its\nboard of direc...
# 1     Shr 34 cts vs 1.19 dlrs\n    Net 807,000 vs 2,...
# 2     Oper shr loss two cts vs profit seven cts\n   ...
# 3     Shr one dlr vs 73 cts\n    Net 12.6 mln vs 15....
# 4     Dean Foods Co expects earnings for the\nfourth...
# ...                                                 ...
# 7013  U.K. Chancellor of the Exchequer Nigel\nLawson...
# 7014  President Reagan said he was pleased\nwith the...
# 7015  The Federal Reserve entered the\ngovernment se...
# 7016  Federal Deposit Insurance Corp Chairman\nWilli...
# 7017  The thriving market in Luxembourg\nfranc bond ...
#
#                             date        topics                 places     id  \
# 0     1987-02-26 15:17:11.200000      ['earn']                  [usa]      9
# 1     1987-02-26 15:18:59.340000      ['earn']                  [usa]     11
# 2     1987-02-26 15:20:13.090000      ['earn']                  [usa]     13
# 3     1987-02-26 15:20:27.170000      ['earn']                  [usa]     14
# 4     1987-02-26 15:26:26.780000      ['earn']                  [usa]     18
# ...                          ...           ...                    ...    ...
# 7013  1987-10-20 14:16:22.140000  ['interest']                   [uk]  20532
# 7014  1987-10-20 17:16:07.650000  ['interest']                  [usa]  20769
# 7015  1987-10-19 11:55:16.350000  ['interest']                  [usa]  21285
# 7016  1987-10-19 11:09:59.740000  ['interest']                  [usa]  21342
# 7017  1987-10-19 08:22:10.280000  ['interest']  [luxembourg, belgium]  21491
#
#      organisations                                         clean_text  \
# 0          unknown  champion product inc said board director appro...
# 1          unknown  shr ct vs dlr net vs asset mln vs mln deposit ...
# 2          unknown  oper shr loss two ct vs profit seven ct oper s...
# 3          unknown  shr one dlr vs ct net mln vs mln rev mln vs ml...
# 4          unknown  dean food co expect earn fourth quarter end ma...
# ...            ...                                                ...
# 7013       unknown  uk chancellor exchequ nigel lawson said collap...
# 7014       unknown  presid reagan said pleas action bank reduc pri...
# 7015       unknown  feder reserv enter govern secur market arrang ...
# 7016       unknown  feder deposit insur corp chairman william seid...
# 7017       unknown  thrive market luxembourg franc bond issu tempo...
#
#                                             postag_text topics_clean
# 0     [(champion, NN), (product, NN), (inc, NN), (sa...       'earn'
# 1     [(shr, NN), (ct, NN), (vs, JJ), (dlr, JJ), (ne...       'earn'
# 2     [(oper, IN), (shr, JJ), (loss, NN), (two, CD),...       'earn'
# 3     [(shr, VB), (one, CD), (dlr, NN), (vs, NN), (c...       'earn'
# 4     [(dean, NN), (food, NN), (co, NN), (expect, VB...       'earn'
# ...                                                 ...          ...
# 7013  [(uk, JJ), (chancellor, NN), (exchequ, NN), (n...   'interest'
# 7014  [(presid, NN), (reagan, NN), (said, VBD), (ple...   'interest'
# 7015  [(feder, NN), (reserv, NN), (enter, NN), (gove...   'interest'
# 7016  [(feder, NN), (deposit, NN), (insur, VBP), (co...   'interest'
# 7017  [(thrive, JJ), (market, NN), (luxembourg, NN),...   'interest'
#
# [7018 rows x 10 columns]

# %%
type(little['topics_clean'])
# Out:
# pandas.core.series.Series

# %%
little['topics_clean']
# Out:
# 0           'earn'
# 1           'earn'
# 2           'earn'
# 3           'earn'
# 4           'earn'
#            ...
# 7013    'interest'
# 7014    'interest'
# 7015    'interest'
# 7016    'interest'
# 7017    'interest'
# Name: topics_clean, Length: 7018, dtype: object

# %%
# Function to remove quotation marks
def remove_comillas(string):
    comillas = "''"
    string = "".join([i for i in string if i not in comillas])
    return string

# %%
#Removing quotation marks
little['topics_clean'] = little['topics_clean'].apply(lambda x: remove_comillas(x))

# %%
little
# Out:
#                                                   title  \
# 0           CHAMPION PRODUCTS <CH> APPROVES STOCK SPLIT
# 1                           COBANCO INC <CBCO> YEAR NET
# 2              AM INTERNATIONAL INC <AM> 2ND QTR JAN 31
# 3                    BROWN-FORMAN INC <BFD> 4TH QTR NET
# 4          DEAN FOODS <DF> SEES STRONG 4TH QTR EARNINGS
# ...                                                 ...
# 7013   LAWSON SAYS UK INTEREST RATE PROSPECTS UNCHANGED
# 7014        REAGAN SEES ROOM FOR INTEREST RATE DECLINES
# 7015                FED ARRANGES THREE-DAY SYSTEM REPOS
# 7016  FDIC'S SEIDMAN SAYS HIGHER RATES COULD HARM BANKS
# 7017    LUX FRANC BOND MARKET STALLED BY BELGIAN CRISIS
#
#                                                    body  \
# 0     Champion Products Inc said its\nboard of direc...
# 1     Shr 34 cts vs 1.19 dlrs\n    Net 807,000 vs 2,...
# 2     Oper shr loss two cts vs profit seven cts\n   ...
# 3     Shr one dlr vs 73 cts\n    Net 12.6 mln vs 15....
# 4     Dean Foods Co expects earnings for the\nfourth...
# ...                                                 ...
# 7013  U.K. Chancellor of the Exchequer Nigel\nLawson...
# 7014  President Reagan said he was pleased\nwith the...
# 7015  The Federal Reserve entered the\ngovernment se...
# 7016  Federal Deposit Insurance Corp Chairman\nWilli...
# 7017  The thriving market in Luxembourg\nfranc bond ...
#
#                             date        topics                 places     id  \
# 0     1987-02-26 15:17:11.200000      ['earn']                  [usa]      9
# 1     1987-02-26 15:18:59.340000      ['earn']                  [usa]     11
# 2     1987-02-26 15:20:13.090000      ['earn']                  [usa]     13
# 3     1987-02-26 15:20:27.170000      ['earn']                  [usa]     14
# 4     1987-02-26 15:26:26.780000      ['earn']                  [usa]     18
# ...                          ...           ...                    ...    ...
# 7013  1987-10-20 14:16:22.140000  ['interest']                   [uk]  20532
# 7014  1987-10-20 17:16:07.650000  ['interest']                  [usa]  20769
# 7015  1987-10-19 11:55:16.350000  ['interest']                  [usa]  21285
# 7016  1987-10-19 11:09:59.740000  ['interest']                  [usa]  21342
# 7017  1987-10-19 08:22:10.280000  ['interest']  [luxembourg, belgium]  21491
#
#      organisations                                         clean_text  \
# 0          unknown  champion product inc said board director appro...
# 1          unknown  shr ct vs dlr net vs asset mln vs mln deposit ...
# 2          unknown  oper shr loss two ct vs profit seven ct oper s...
# 3          unknown  shr one dlr vs ct net mln vs mln rev mln vs ml...
# 4          unknown  dean food co expect earn fourth quarter end ma...
# ...            ...                                                ...
# 7013       unknown  uk chancellor exchequ nigel lawson said collap...
# 7014       unknown  presid reagan said pleas action bank reduc pri...
# 7015       unknown  feder reserv enter govern secur market arrang ...
# 7016       unknown  feder deposit insur corp chairman william seid...
# 7017       unknown  thrive market luxembourg franc bond issu tempo...
#
#                                             postag_text topics_clean
# 0     [(champion, NN), (product, NN), (inc, NN), (sa...         earn
# 1     [(shr, NN), (ct, NN), (vs, JJ), (dlr, JJ), (ne...         earn
# 2     [(oper, IN), (shr, JJ), (loss, NN), (two, CD),...         earn
# 3     [(shr, VB), (one, CD), (dlr, NN), (vs, NN), (c...         earn
# 4     [(dean, NN), (food, NN), (co, NN), (expect, VB...         earn
# ...                                                 ...          ...
# 7013  [(uk, JJ), (chancellor, NN), (exchequ, NN), (n...     interest
# 7014  [(presid, NN), (reagan, NN), (said, VBD), (ple...     interest
# 7015  [(feder, NN), (reserv, NN), (enter, NN), (gove...     interest
# 7016  [(feder, NN), (deposit, NN), (insur, VBP), (co...     interest
# 7017  [(thrive, JJ), (market, NN), (luxembourg, NN),...     interest
#
# [7018 rows x 10 columns]

# %%
#Checking how much data we have left from the original dataset
percentage1 = round((little.shape[0]/before)*100,2)
print("The percentage left of data is: ",percentage1,"%")
# Out:
# The percentage left of data is:  32.52 %

# %% [markdown]
# # SEGUIR CHECANDO EL TFIDF, TAGGS OCCURENCE Y CHECAR LA RED NEURONAL

# %%
#Choosing the column in which we might work
nice = little[['body','clean_text', 'postag_text', 'topics_clean']]

# %%
nice
# Out:
#                                                    body  \
# 0     Champion Products Inc said its\nboard of direc...
# 1     Shr 34 cts vs 1.19 dlrs\n    Net 807,000 vs 2,...
# 2     Oper shr loss two cts vs profit seven cts\n   ...
# 3     Shr one dlr vs 73 cts\n    Net 12.6 mln vs 15....
# 4     Dean Foods Co expects earnings for the\nfourth...
# ...                                                 ...
# 7013  U.K. Chancellor of the Exchequer Nigel\nLawson...
# 7014  President Reagan said he was pleased\nwith the...
# 7015  The Federal Reserve entered the\ngovernment se...
# 7016  Federal Deposit Insurance Corp Chairman\nWilli...
# 7017  The thriving market in Luxembourg\nfranc bond ...
#
#                                              clean_text  \
# 0     champion product inc said board director appro...
# 1     shr ct vs dlr net vs asset mln vs mln deposit ...
# 2     oper shr loss two ct vs profit seven ct oper s...
# 3     shr one dlr vs ct net mln vs mln rev mln vs ml...
# 4     dean food co expect earn fourth quarter end ma...
# ...                                                 ...
# 7013  uk chancellor exchequ nigel lawson said collap...
# 7014  presid reagan said pleas action bank reduc pri...
# 7015  feder reserv enter govern secur market arrang ...
# 7016  feder deposit insur corp chairman william seid...
# 7017  thrive market luxembourg franc bond issu tempo...
#
#                                             postag_text topics_clean
# 0     [(champion, NN), (product, NN), (inc, NN), (sa...         earn
# 1     [(shr, NN), (ct, NN), (vs, JJ), (dlr, JJ), (ne...         earn
# 2     [(oper, IN), (shr, JJ), (loss, NN), (two, CD),...         earn
# 3     [(shr, VB), (one, CD), (dlr, NN), (vs, NN), (c...         earn
# 4     [(dean, NN), (food, NN), (co, NN), (expect, VB...         earn
# ...                                                 ...          ...
# 7013  [(uk, JJ), (chancellor, NN), (exchequ, NN), (n...     interest
# 7014  [(presid, NN), (reagan, NN), (said, VBD), (ple...     interest
# 7015  [(feder, NN), (reserv, NN), (enter, NN), (gove...     interest
# 7016  [(feder, NN), (deposit, NN), (insur, VBP), (co...     interest
# 7017  [(thrive, JJ), (market, NN), (luxembourg, NN),...     interest
#
# [7018 rows x 4 columns]

# %%
#Used to encode the topics classes into numbers
from sklearn import preprocessing

# %%
#Calling the method LabelEncoder
le = preprocessing.LabelEncoder()

# %%
#Encoding the topics classes into numbers
nice['topics_clean'] = le.fit_transform(nice.topics_clean.values)
# Out:
# C:\Users\Usuario\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
nice
# Out:
#                                                    body  \
# 0     Champion Products Inc said its\nboard of direc...
# 1     Shr 34 cts vs 1.19 dlrs\n    Net 807,000 vs 2,...
# 2     Oper shr loss two cts vs profit seven cts\n   ...
# 3     Shr one dlr vs 73 cts\n    Net 12.6 mln vs 15....
# 4     Dean Foods Co expects earnings for the\nfourth...
# ...                                                 ...
# 7013  U.K. Chancellor of the Exchequer Nigel\nLawson...
# 7014  President Reagan said he was pleased\nwith the...
# 7015  The Federal Reserve entered the\ngovernment se...
# 7016  Federal Deposit Insurance Corp Chairman\nWilli...
# 7017  The thriving market in Luxembourg\nfranc bond ...
#
#                                              clean_text  \
# 0     champion product inc said board director appro...
# 1     shr ct vs dlr net vs asset mln vs mln deposit ...
# 2     oper shr loss two ct vs profit seven ct oper s...
# 3     shr one dlr vs ct net mln vs mln rev mln vs ml...
# 4     dean food co expect earn fourth quarter end ma...
# ...                                                 ...
# 7013  uk chancellor exchequ nigel lawson said collap...
# 7014  presid reagan said pleas action bank reduc pri...
# 7015  feder reserv enter govern secur market arrang ...
# 7016  feder deposit insur corp chairman william seid...
# 7017  thrive market luxembourg franc bond issu tempo...
#
#                                             postag_text  topics_clean
# 0     [(champion, NN), (product, NN), (inc, NN), (sa...             2
# 1     [(shr, NN), (ct, NN), (vs, JJ), (dlr, JJ), (ne...             2
# 2     [(oper, IN), (shr, JJ), (loss, NN), (two, CD),...             2
# 3     [(shr, VB), (one, CD), (dlr, NN), (vs, NN), (c...             2
# 4     [(dean, NN), (food, NN), (co, NN), (expect, VB...             2
# ...                                                 ...           ...
# 7013  [(uk, JJ), (chancellor, NN), (exchequ, NN), (n...             3
# 7014  [(presid, NN), (reagan, NN), (said, VBD), (ple...             3
# 7015  [(feder, NN), (reserv, NN), (enter, NN), (gove...             3
# 7016  [(feder, NN), (deposit, NN), (insur, VBP), (co...             3
# 7017  [(thrive, JJ), (market, NN), (luxembourg, NN),...             3
#
# [7018 rows x 4 columns]

# %%
#How many element we have per each class
nice.topics_clean.value_counts()
# Out:
# 2    3735
# 0    2125
# 1     355
# 5     333
# 4     259
# 3     211
# Name: topics_clean, dtype: int64

# %% [markdown]
# ### POS TAGGING

# %%
class pos_tagging(object):
    
    #Getting lexico
    def get_lexic(self, tokens, lexic):
        for word in tokens:
            if word in lexic.keys():
                lexic[word] += 1
            else:
                lexic[word] = 1
        return lexic
    
    #Given on the frecuency of each item in lexico, it gets its probability
    def get_lexic_prob(self,lexic):
        lexic_prob = lexic
        lexic_lenght = sum(lexic_prob.values())
        for word in lexic:
            lexic_prob[word] = lexic_prob[word]/lexic_lenght
        return lexic_prob
    
    #Grabbing tags
    def grab_pos_tag(self, string):
        pos = []
        for i in string:
            pos_token = nltk.pos_tag(i.split())
            pos.append(pos_token[0][1])
        return pos
    
    #Bigrams and probabilities of the chains method
    def get_lex_bi(self, pos_tag):
        lexic = {}
        total = 0
        for bigram in list(bigrams(pos_tag)):
            if bigram in lexic.keys():
                    lexic[bigram] += 1
            else:
                lexic[bigram] = 1
            total +=1 
        for i in lexic.keys():
            lexic[i] = lexic[i]/total
            
        lexic_sor = sorted(lexic.items(), key=operator.itemgetter(1), reverse=True)
        return lexic_sor

# %%
lexical = pos_tagging()
lexic = {}
pos_tag_list = []

# %%
for i in df["clean_text"]:
    clean_list =list(i)
    tokenizer = word_tokenize(("".join(clean_list)))
    lexic.update(lexical.get_lexic(tokenizer, lexic))
    lexic_prob = lexical.grab_pos_tag(tokenizer)
    pos_tag_list += lexic_prob
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-46-2b3714caf801> in <module>
#       3     tokenizer = word_tokenize(("".join(clean_list)))
#       4     lexic.update(lexical.get_lexic(tokenizer, lexic))
# ----> 5     lexic_prob = lexical.grab_pos_tag(tokenizer)
#       6     pos_tag_list += lexic_prob
#
# <ipython-input-44-10325775235e> in grab_pos_tag(self, string)
#      22         pos = []
#      23         for i in string:
# ---> 24             pos_token = nltk.pos_tag(i.split())
#      25             pos.append(pos_token[0][1])
#      26         return pos
#
# ~\anaconda3\lib\site-packages\nltk\tag\__init__.py in pos_tag(tokens, tagset, lang)
#     124     :rtype: list(tuple(str, str))
#     125     """
# --> 126     tagger = _get_tagger(lang)
#     127     return _pos_tag(tokens, tagset, tagger)
#     128
#
# ~\anaconda3\lib\site-packages\nltk\tag\__init__.py in _get_tagger(lang)
#      88         tagger.load(ap_russian_model_loc)
#      89     else:
# ---> 90         tagger = PerceptronTagger()
#      91     return tagger
#      92
#
# ~\anaconda3\lib\site-packages\nltk\tag\perceptron.py in __init__(self, load)
#     138         self.classes = set()
#     139         if load:
# --> 140             AP_MODEL_LOC = 'file:'+str(find('taggers/averaged_perceptron_tagger/'+PICKLE))
#     141             self.load(AP_MODEL_LOC)
#     142
#
# ~\anaconda3\lib\site-packages\nltk\data.py in find(resource_name, paths)
#     612
#     613         # Is the path item a directory or is resource_name an absolute path?
# --> 614         elif not path_ or os.path.isdir(path_):
#     615             if zipfile is None:
#     616                 p = os.path.join(path_, url2pathname(resource_name))
#
# KeyboardInterrupt:

# %%
#Making copy of lexic
wordsbag = lexic.copy()
#Get probability of word appeared on lexic
lexic_prob = lexical.get_lexic_prob(lexic) 
bigram_prob = lexical.get_lexic(pos_tag_list)

# %%
class get_tfidf:
    def TF(item, lexic):
        lexic_len = len(lexic)
        tf = {}
        for word, count in item.items():
            tf[word] = count / float(lexic_len)
        return tf

    def IDF(item):
        len_item = len(item)
        IDF = dict.fromkeys(item[0].keys(), 0)
        for document in item:
            for i, j in document.items():
                if j > 0:
                    IDF[i] += 1
        for i, j in IDF.items():
            IDF[i] = math.log(len_item / float(j))
        return IDF

    def TFIDF(item, idf):
        tf_idf = {}
        for i, j in item.items():
            tf_idf[i] = j * idf[i]
        return tf_idf

# %%
lexic

# %%
BagOfWords = set(lexic)
posdic = dict.fromkeys(BagOfWords, 0) 
for i in lexic:
    posdic[i] += 1

# %%
tfpos = get_tfidf.TF(posdic, BagOfWords)
tfidfpos = get_tfidf.TFIDF(tfpos, tfpos)

# %% [markdown]
# ## MAY BE NOT

# %%
"""#Choosing the column for doing the pos tagging tasks
string = nice['clean_text']"""

# %%
"""class post_tag(object):

    def __init__(self, pos_tag_list=[], lexico_dict={}):
        self.pos_tag_list = pos_tag_list
        self.lexico_dict = lexico_dict

    #Calling methods
    def work(self, string):
        #pos_tag = []
        #lexico = {}
        for i in string:
            mylist = list(i)
            mylist = word_tokenize(("".join(i)))
            self.lexico_dict.update(self.lexicon(mylist,self.lexico_dict))
            bigram_prob = self.pos_tag
            lexic_prob = self.prob_lexico
            temp_pos=self.pos_tag(mylist)
            self.pos_tag_list+=temp_pos
        return self, bigram_prob, lexic_prob

    #Getting lexico
    def lexicon(self, mylist, lexico_dict):
        for word in mylist:
            if word in lexico_dict.keys():
                lexico_dict[word] += 1
            else:
                lexico_dict[word] = 1
        return lexico_dict

    #Given on the frecuency of each item in lexico, it gets its probability
    def prob_lexico(self,lexico_dict):
        lex_prob = lexico_dict
        len_lex = sum(lex_prob.values())
        for word in lexico_dict:
            lex_prob[word] = lex_prob[word]/len_lex
        return lex_prob

    #Grabbing tags
    def pos_tag(self,string):
        POS,Token=[],[]
        for word in string:
            pos_token = nltk.pos_tag(word.split())
            POS.append(pos_token[0][1])
        return POS

    #Getting bigrams and probabilities
    def bigrams_prob(self, pos_tag):
        lexic = {}
        total=0
        for bigram in list(bigrams(POS_tag)):
            if bigram in lexic.keys():
                    lexic[bigram] += 1
            else:
                lexic[bigram] = 1
            total+=1
        for i in lexic.keys():
            lexic[i]= lexic[i]/total
            
        sorted_lexic = sorted(lexic.items(), key=operator.itemgetter(1), reverse=True)
        return sorted_lexic"""

# %%
#postaging = post_tag()

# %%
#mylist = []
#lexico_dict = {}

# %%
"""mylist = []
lexico_dict = {}
for i in nice['clean_text']:
    mylist = list(i)
    tokenizer = word_tokenize(("".join(mylist)))
    lexico_dict.update(postaging.lexicon(mylist,lexico_dict))
    temp_pos=postaging.pos_tag(tokenizer)
    mylist += temp_pos"""

# %%
#lexico_dict

# %%
#temp_pos

# %%
"""a = postaging.lexicon(mylist,lexico_dict)
a"""

# %%
#check, uno, dos = postaging.work(string)

# %%
#uno

# %%
#import pickle

# %%
#pickle.dump(df, open('unit1.pickle','wb'))

# %%
#clean = list(df['clean_text'])

# %%
"""all_tags = []
tags = nltk.pos_tag(clean)
tags.insert(0,(" ",'-s-'))
all_tags.append(tags)"""

# %%
#all_tags

# %%
"""def get_pos(string):
    string = nltk.word_tokenize(string)
    pos_string = nltk.pos_tag(string)
    return pos_string"""

# %%
#clean = list(df['clean_text'])

# %%
#get_pos(clean)

# %%
#get_pos(clean)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer()
vectors = vectorizer.fit_transform(df.clean_text.tolist())
feature_names = vectorizer.get_feature_names()
dense = vectors.todense()
denselist = dense.tolist()
tfidf = pd.DataFrame(denselist, columns=feature_names)

# %%
from sklearn.linear_model import LogisticRegression
clf = LogisticRegression(random_state=0).fit(tfidf, df.topics_clean)

# %%
clf.score(tfidf, df.topics_clean)
